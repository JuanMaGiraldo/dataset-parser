# %%
import pandas as pd
import matplotlib.pyplot as plt
import re

hurts = pd.read_csv('dataset.csv')
hurts.head()
# Out:
# /home/juanma/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (18,19) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#       Fecha Departamento Municipio     Día      Hora           Barrio    Zona  \
# 0  1/1/2019    ANTIOQUIA     BELLO  Martes  12:00:00            PEREZ  URBANA
# 1  1/1/2019    ANTIOQUIA     BELLO  Martes  06:00:00      LA CABAÑITA  URBANA
# 2  1/1/2019    ANTIOQUIA     BELLO  Martes  21:30:00        LAS VEGAS  URBANA
# 3  1/1/2019    ANTIOQUIA     BELLO  Martes  22:00:00       LOS SAUCES  URBANA
# 4  1/1/2019    ANTIOQUIA     BELLO  Martes  01:30:00  NIQUIA QUITASOL  URBANA
#
#                     Clase de sitio                Arma empleada Móvil Agresor  \
# 0  RODANDO SOBRE VIA - VIA PUBLICA          SIN EMPLEO DE ARMAS         A PIE
# 1                    VIAS PUBLICAS          SIN EMPLEO DE ARMAS         A PIE
# 2                           PUENTE  ARMA BLANCA / CORTOPUNZANTE         A PIE
# 3                    VIAS PUBLICAS          SIN EMPLEO DE ARMAS         A PIE
# 4                           BANCOS          SIN EMPLEO DE ARMAS         A PIE
#
#    ...       Sexo Estado civil País de nacimiento    Clase de empleado  \
# 0  ...  MASCULINO     SEPARADO           COLOMBIA  EMPLEADO PARTICULAR
# 1  ...  MASCULINO      SOLTERO           COLOMBIA  EMPLEADO PARTICULAR
# 2  ...   FEMENINO       CASADO           COLOMBIA           ESTUDIANTE
# 3  ...   FEMENINO      SOLTERO           COLOMBIA  EMPLEADO PARTICULAR
# 4  ...  MASCULINO       CASADO           COLOMBIA  EMPLEADO PARTICULAR
#
#                              Profesión Escolaridad Código DANE Cantidad  \
# 0     TECNOLOGO  EN GESTION INDUSTRIAL   TECNOLOGO     5088000        1
# 1                ANALISTAS DE SISTEMAS   TECNOLOGO     5088000        1
# 2  ADMINISTRACION  EN RECURSOS HUMANOS    SUPERIOR     5088000        1
# 3                         NO REPORTADA  SECUNDARIA     5088000        1
# 4                   CIENCIAS MILITARES  SECUNDARIA     5088000        1
#
#   Unnamed: 20 Unnamed: 21
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# 4         NaN         NaN
#
# [5 rows x 22 columns]

# %%
hurts.shape
# Out:
# (143696, 22)

# %%
hurts.isna().sum()
# Out:
# Fecha                      0
# Departamento               0
# Municipio                  0
# Día                        0
# Hora                       0
# Barrio                     0
# Zona                       0
# Clase de sitio             0
# Arma empleada              0
# Móvil Agresor              0
# Móvil Victima              0
# Edad                       0
# Sexo                       0
# Estado civil               0
# País de nacimiento         0
# Clase de empleado          0
# Profesión                  0
# Escolaridad                0
# Código DANE                0
# Cantidad                   0
# Unnamed: 20           143695
# Unnamed: 21           143695
# dtype: int64

# %%
df = pd.DataFrame(hurts,columns=['Hora','Edad'])
df['Edad'] = df['Edad'].replace('-',20,regex=True).astype(float)
df['Hora'] = df['Hora'].replace(':','',regex=True).astype(float)
plt.scatter(df['Hora'], df['Edad'])
plt.show()

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=4).fit(df)
centroids = kmeans.cluster_centers_
print(centroids)
# Out:
# [[7.86803181e+04 3.51473565e+01]
#  [1.97298664e+05 3.37747987e+01]
#  [1.38436217e+04 3.32772172e+01]
#  [1.35241528e+05 3.60533182e+01]]

# %%
plt.scatter(df['Hora'], df['Edad'],c=kmeans.labels_.astype(float), s=50,alpha=0.5)
plt.scatter(centroids[:,0],centroids[:,1],c='red',s=50)
plt.show()
